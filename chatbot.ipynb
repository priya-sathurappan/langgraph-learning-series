# %%
from typing import TypedDict, Annotated

import langchain_google_genai
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model("google_genai:gemini-2.0-flash")
#llm.invoke("who won the fifa world cup in 2022?")
# Out:
# AIMessage(content='Argentina won the FIFA World Cup in 2022.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c130f-7d47-7b40-a363-0252501b210b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 14, 'total_tokens': 28, 'input_token_details': {'cache_read': 0}})

# %%
from langgraph.graph import StateGraph, START, END, add_messages
from typing import TypedDict, Annotated

class State(TypedDict):
    messages:Annotated[list,add_messages]

def chatbot(state:State) -> State:
    return {
        "messages": [llm.invoke(state["messages"])]
    }

builder = StateGraph(State)
builder.add_node("chatbot_node",chatbot)
builder.add_edge(START,"chatbot_node")
builder.add_edge("chatbot_node",END)
graph = builder.compile()

# %%
response = graph.invoke({
    "messages":[
        {"role":"system","content":"You are a helpful assistant.Be thankful in answering questions."},
        {"role":"user","content":"who won the fifa world cup in 2022?"}
    ]
})

# %%
response["messages"]
# Out:
# [SystemMessage(content='You are a helpful assistant.Be thankful in answering questions.', additional_kwargs={}, response_metadata={}, id='1db8b5d1-e9fb-4725-818a-29557b04b2ed'),
#  HumanMessage(content='who won the fifa world cup in 2022?', additional_kwargs={}, response_metadata={}, id='353099eb-af5f-4829-9f3d-dd3db6d1a8d0'),
#  AIMessage(content="Argentina won the FIFA World Cup in 2022! I'm happy to provide you with that information.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c1318-86d4-7013-b284-db6316b5b4b3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 25, 'total_tokens': 51, 'input_token_details': {'cache_read': 0}})]
